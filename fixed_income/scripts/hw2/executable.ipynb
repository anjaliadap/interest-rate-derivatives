# %%
# %run "C:\Users\anjal\Desktop\Fordham\Spring 2026\Interest Rate Derivatives\Homework\fixed_income\scripts\hw2\hw2.py"
# Out:
# Q3 — Nelson–Siegel (NS) results
# Settlement date: 2025-11-12
# Parameters: [ 0.05271537 -0.00672575 -0.04203873  0.          2.34871569  1.        ]
# Objective value: 7433.934166695606
# Success: True
#
# Q4 — Nelson–Siegel–Svensson (NSS, free taus) results
# Parameters: [ 3.26840098e-02  1.04725494e-02 -4.80145091e-02  7.29460477e-02
#   3.94336863e+00  1.07501505e+01]
# Objective value: 7398.993602771336
# Success: True
#
# Q5 — NSS (fixed taus) results
# tau1: 4.0 tau2: 10.75
# Parameters: [ 0.03216701  0.01093942 -0.04879139  0.07516282  4.         10.75      ]
# Objective value: 7399.465607821168
# Success: True
#
# Curve table (NS):
#        t_years  zero_rate_cont  discount_factor
# 0    0.083333        0.045379         0.996226
# 1    0.250000        0.044250         0.988998
# 2    0.500000        0.042770         0.978842
# 3    1.000000        0.040466         0.960342
# 4    2.000000        0.037828         0.927135
# 5    3.000000        0.036901         0.895204
# ...

# %% [markdown]
# ## Results Summary
#
# The NSS model with free taus provides the best average fit to bond prices, but exhibits extremely high parameter correlations and significantly larger parameter volatility, indicating strong factor interaction and instability.
#
# Fixing the decay parameters (τ₁ = 4.0, τ₂ = 10.75) results in a negligible loss of fit quality while materially improving parameter stability and reducing correlation.
#
# The NS model is the most stable but provides the weakest fit.
#
# Overall, the fixed-tau NSS specification offers the best trade-off between fit quality and parameter stability.
