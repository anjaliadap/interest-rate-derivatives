# %%
# %run q1.py
# Out:
# The 6M-12M forward rate starting in 6M is: 3.294%

# %%
# %run USTreasuryBond.py
# Out:
# ---------------- QUESTION 2 ----------------
#
# Bond Results (per $100 notional):
# Quoted Price: 100.000000
# Accrued Interest: 0.651934
# Yield to Maturity: 3.999461%
# DV01: 0.080683 per 1 bp change in yield
# DV01 (per $1mm): 806.83
# Convexity: 0.000077 per (1 bp)^2 change in yield
# Convexity (Following Bloomberg): 0.767
#
# ---------------- QUESTION 4 ----------------
# ---------------- QUESTION 5 ----------------
# ---------------- QUESTION 6 ----------------
# The DV01-only PnL attribution results in a wide and skewed error distribution due to nonlinear price–yield effects.
# Including convexity significantly reduces the magnitude and dispersion of the error, producing a tighter and more symmetric distribution centered near zero.
#
# ---------------- QUESTION 7 ----------------
#
#
# Position DV01s (Dollar DV01 per 1bp):
#  CT2: Notional =    1,000 MM | Position DV01 = $  188,536.23 per bp
#  CT3: Notional =      500 MM | Position DV01 = $  141,469.03 per bp
# ...
